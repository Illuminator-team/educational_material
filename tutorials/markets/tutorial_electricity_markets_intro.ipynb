# %% [markdown]
# # Practical Financial Balance in Electricity Markets

# %%
# If running notebook within Google colab, install illuminator and clone educational_material repo to access notebook supporting data
if "google.colab" in str(get_ipython()):
  # !pip install Illuminator
  # !git clone https://github.com/Illuminator-team/educational_material.git

# %%
# If running notebook within Google colab, access the right path of the educational material repo
if "google.colab" in str(get_ipython()):
  import sys
  sys.path.append('/content/educational_material/tutorials/markets/')
  # %cd /content/educational_material/tutorials/markets/

# %% [markdown]
# #### Importing the needed packages
# The first step in every python notebook is to install the needed packages (e.g. [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) for data management) as well as functions and classes from external scripts.

# %%
# !pip install seaborn

# %% [markdown]
# <style>
# .custom-text {
#   color: darkblue;
# }
# @media (prefers-color-scheme: dark) {
#   .custom-text {
#     color: lightblue;
#   }
# }
# </style>

# %%
from illuminator.engine import Simulation
import functions_T2
import pandas as pd
import nest_asyncio
nest_asyncio.apply()
from IPython.display import HTML

# %% [markdown]
# #### The Value of Electricity
# One key characteristic of electricity as a good is the difficulty of storing it. Because of this, supply and demand must be continuously balanced in the electricity grid. The electricity demand throughout the day depends on the consumer pattern. Therefore, electricity has a different market value at different hours of the day. Furthermore, electricity prices are also strongly dependent on fuel costs (e.g. natural gas) and $\text{CO}_2$ prices. Additional information can be found on: https://www.tennet.eu/de-en/markets/european-electricity-market-model-and-market-coupling
#
# #### Day-Ahead Market
# On the day-ahead market, participants can sell and buy electricity in a pan-European auction for the next day in hourly blocks. The day-ahead market is cleared at 12:00 o’clock noon each day of the year. During market clearning, the intersection of demand and offered quantity (supply) determines the electricity price and volume for each hour. This price is then either paid (consumers) or received (suppliers) by all market participants who were successful in the auction.
#
# Because the day-ahead market is organized short before delivery and has a single clearing price (per hour), it reflects the value of electricity during different hours the best. The clearing price of the day-ahead market is therefore often referred to as “the electricity price”. The price is determined per bidding zone, which in Europe mostly corresponds to the borders of a country.
#
# Source: https://www.eles.si/Portals/0/Novice/DOKUMENTI/181201_DA%20Scheduled%20Exchanges%20Calc%20Methodology.pdf
#
# #### Introduction: The Market in this Tutorial
# The market in this tutorial is mimicking a single hour in the European Day-Ahead Market. There are three (and in the last exercise four) companies competing, which bid their power plants in a single price auction. The demand in this tutorial is completely inelastic (set to a fixed value).
#
# Side Note: The bidding prices for the different generation sources are based on Marginal Costs (fuel, CO2 emissions, and variable O&M),as marginal pricing determines the merit order in the Day-Ahead Market. For conventional plants (Gas, Coal, Nuclear, Oil), these costs are estimated using recent European and Dutch market data.
# For renewables, the marginal costs are assumed to be zero, as they incur no fuel costs and have minimal variable maintenance, reflecting standard market dynamics.
#
# Sources:\
#          Gas (CCGT):https://energy.ec.europa.eu/data-and-analysis/market-analysis_en\
#          Coal: https://www.iea.org/reports/coal-2023\
#          Nuclear: https://www.iea.org/reports/projected-costs-of-generating-electricity-2020\
#          Oil: https://www.iea.org/reports/electricity-2024\
#          Hydro and Other Renewables: https://www.irena.org/Publications/2024/Sep/Renewable-power-generation-costs-in-2023\
#
#
# <img src="images/Installed_capacity_per_company_graphic.png" alt="companies portfolio" width="800">
#
# The Portfolios of the 3 companies can also be seen in the table below. The table also displays the variable costs of each generation unit of each company.
#
# <img src="images/portfolios_companies.png" alt="T2_companies" width="800">

# %% [markdown]
# <span class="custom-text">
#
# ##### Task 1: Day-Ahead Market with Conventional Generation
#
# In this task, the 3 companies own different types of conventional power plants that they use to bid in the Day-Ahead Market.
#
# a) Run the simulation with the code below and generate the Merit Order Curve with the create_merit_order_curve function in the following cell. Looking at the market result presented in the Merit Order Curve what do you observe? Elaborate on how the market clearing is determined.
#
# b) Do some companies have advantages over others? If yes, why is that the case?
#
# c) How does a decrease or increase in demand change the result (you can experiment by adjusting the `demand` value in the code below)?
#
# </span>

# %%
# %%capture
CONFIG_FILE = 'data/Tutorial_market_conventional_case.yaml'
simulation_conventional = Simulation(CONFIG_FILE)
demand = 3000

portfolio_company_1 = [
        {'Technology': 'Oil', 'Capacity (MW)': 300, 'Cost (€/MWh)': 200, 'Availability': 1},
        {'Technology': 'Nuclear', 'Capacity (MW)': 700, 'Cost (€/MWh)': 10, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 400, 'Cost (€/MWh)': 95, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 200, 'Cost (€/MWh)': 130, 'Availability': 1}
    ]

portfolio_company_2 = [
        {'Technology': 'Coal', 'Capacity (MW)': 600, 'Cost (€/MWh)': 75, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 500, 'Cost (€/MWh)': 90, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 150, 'Cost (€/MWh)': 125, 'Availability': 1},
        {'Technology': 'Hydro', 'Capacity (MW)': 150, 'Cost (€/MWh)': 0, 'Availability': 1}
    ]

portfolio_company_3 = [
        {'Technology': 'Coal', 'Capacity (MW)': 550, 'Cost (€/MWh)': 70, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 550, 'Cost (€/MWh)': 85, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 200, 'Cost (€/MWh)': 120, 'Availability': 1},
        {'Technology': 'Hydro','Capacity (MW)': 100, 'Cost (€/MWh)': 0, 'Availability': 1}
    ]
#simulation_conventional.set_input('Operator1', 'demand', demand)

simulation_conventional.run()
# Out:
# 2026-02-20 11:56:00.949 | INFO     | mosaik.async_scenario:start:508 - Starting 'Collector-0' (based on starter 'Collector')
# 2026-02-20 11:56:03.071 | INFO     | mosaik.async_scenario:start:508 - Starting 'CSV_operator-0' (based on starter 'CSV_operator')
# 2026-02-20 11:56:03.254 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator CSV_operator-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:03.254 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company1-0' (based on starter 'Company1')
# 2026-02-20 11:56:03.263 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:03.263 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company2-0' (based on starter 'Company2')
# 2026-02-20 11:56:03.263 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company2-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:03.263 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company3-0' (based on starter 'Company3')
# 2026-02-20 11:56:03.271 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company3-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:03.274 | INFO     | mosaik.async_scenario:start:508 - Starting 'Operator1-0' (based on starter 'Operator1')
# 2026-02-20 11:56:03.277 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Operator1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:03.280 | INFO     | mosaik.async_scenario:run:1008 - Starting simulation.
# 2026-02-20 11:56:03.389 | INFO     | mosaik.async_scenario:run:1045 - Simulation finished successfully.

# %%
functions_T2.create_merit_order_curve( all_bids_sorted_csv = r'./results_operator/all_bids_sorted_0.csv', demand = demand, market_result_csv= r'./out_Tutorial2_conventionalgeneration.csv', date = '2024-01-01')

# %% [markdown]
# Now, all three companies have expanded their portofolio by investing in renewable energy, namely solar and wind.
#
# <font color='#3486ca'>
#
# ##### Task 2: Day-Ahead Market with RES Capacities
#
# a) Run the following simulation for the same demands as in task 1 and compare the results. How did the Merit Order curve change? What effect has the integration of renewables on the market balance?
#
# b) Adjust the demand in the same way as you did in task 1. How does the case of renewables compare to the conventional case for a lower and higher demand?
#
# c) What happens if you increase the installed capacity of renewables even more? You can test different levels of demand. </font>

# %%
# %%capture
CONFIG_FILE = 'data/Tutorial_market_RES_case.yaml'
simulation_RES = Simulation(CONFIG_FILE)
demand = 5000

portfolio_company_1 = [
        {'Technology': 'Oil', 'Capacity (MW)': 300, 'Cost (€/MWh)': 200, 'Availability': 1},
        {'Technology': 'Nuclear', 'Capacity (MW)': 700, 'Cost (€/MWh)': 10, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 400, 'Cost (€/MWh)': 95, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 200, 'Cost (€/MWh)': 130, 'Availability': 1},
        {'Technology' : 'Wind', 'Capacity (MW)': 180, 'Cost (€/MWh)': 0, 'Availability': 0.55},
        {'Technology' : 'Solar', 'Capacity (MW)': 100, 'Cost (€/MWh)': 0, 'Availability': 0.34}
    ]

portfolio_company_2 = [
        {'Technology': 'Coal', 'Capacity (MW)': 600, 'Cost (€/MWh)': 75, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 500, 'Cost (€/MWh)': 90, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 150, 'Cost (€/MWh)': 125, 'Availability': 1},
        {'Technology': 'Hydro', 'Capacity (MW)': 150, 'Cost (€/MWh)': 0, 'Availability': 1},
        {'Technology' : 'Wind', 'Capacity (MW)': 250, 'Cost (€/MWh)': 0, 'Availability': 0.55},
        {'Technology' : 'Solar', 'Capacity (MW)': 180, 'Cost (€/MWh)': 0, 'Availability': 0.34}
    ]

portfolio_company_3 = [
        {'Technology': 'Coal', 'Capacity (MW)': 550, 'Cost (€/MWh)': 70, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 550, 'Cost (€/MWh)': 85, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 200, 'Cost (€/MWh)': 120, 'Availability': 1},
        {'Technology': 'Hydro','Capacity (MW)': 100, 'Cost (€/MWh)': 0, 'Availability': 1},
        {'Technology' : 'Wind', 'Capacity (MW)': 200, 'Cost (€/MWh)': 0, 'Availability': 0.55},
        {'Technology' : 'Solar', 'Capacity (MW)': 175, 'Cost (€/MWh)': 0, 'Availability': 0.34}
    ]
simulation_RES.set_model_state('Operator1', 'demand', demand)

simulation_RES.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 CONFIG_FILE = 'data/Tutorial_market_RES_case.yaml'
# ----> 2 simulation_RES = Simulation(CONFIG_FILE)
#       3 demand = 5000
#       5 portfolio_company_1 = [
#       6         {'Technology': 'Oil', 'Capacity (MW)': 300, 'Cost (€/MWh)': 200, 'Availability': 1},
#       7         {'Technology': 'Nuclear', 'Capacity (MW)': 700, 'Cost (€/MWh)': 10, 'Availability': 1},
#    (...)
#      11         {'Technology' : 'Solar', 'Capacity (MW)': 100, 'Cost (€/MWh)': 0, 'Availability': 0.34}
#      12     ]
#
# NameError: name 'Simulation' is not defined

# %%
functions_T2.create_merit_order_curve( all_bids_sorted_csv = r'./results_operator/all_bids_sorted_0.csv', demand = demand, market_result_csv= r'./out_Tutorial2_RESgeneration.csv', date = '2024-01-01')

# %% [markdown]
# <font color="#3486ca">
#
# ##### Task 3: Competing in the Day-Ahead Market
#
# Now you become the forth company (<i>Company 4</i>) on the market with the portfolio according to the `portfolio_own` element. The figure below illustrates the portfolios of all companies. Think of a bidding strategy for each of your generating units. You can adjust your bid capacity and price for the different generation units in the `your_bids` dictionary (actually a dictionary with a list of nested dictionaries).
#
# a) Come up with an initial bidding strategy and run the code. Look at the resulting Merit Order curve and your revenue. How did you do compared to your competitors?
#
# b) Try out at least 3 different bidding strategies and run the simulation. How are you doing compared to your competitors?
#
# c) Draw a final conclusion based on the results for your different strategies: What is a good bidding strategy in your opinion?
#
# d) Bonus: Derive the bidding strategy of your competitors based on all previous results (all follow the same strategy). Can you use this knowledge for your advantage? </font>

# %% [markdown]
# <img src="images/Installed_Capacity_4Companies_RES.svg" alt="T2_companies" width="800">

# %%
# %%capture
#This is the template for your bids. You can adjust the values of the bid capacity and the bid price to try different strategies.
CONFIG_FILE = 'data/Tutorial_market_company4.yaml'
simulation_company_4 = Simulation(CONFIG_FILE)
demand = 6000

your_portfolio = [
        {'Technology': 'Oil', 'Capacity (MW)': 100, 'Cost (€/MWh)': 200, 'Availability': 1},
        {'Technology': 'Coal', 'Capacity (MW)': 600, 'Cost (€/MWh)': 75, 'Availability': 1},
        {'Technology': 'Gas (CCGT)', 'Capacity (MW)': 300, 'Cost (€/MWh)': 90, 'Availability': 1},
        {'Technology': 'Gas (OCGT)', 'Capacity (MW)': 400, 'Cost (€/MWh)': 125, 'Availability': 1},
        {'Technology' : 'Wind', 'Capacity (MW)': 250, 'Cost (€/MWh)': 0, 'Availability': 0.55},
        {'Technology' : 'Solar', 'Capacity (MW)': 100, 'Cost (€/MWh)': 0, 'Availability': 0.34}
    ]

#Please adjust the following bids for your different power plants
your_bids =[
    {'Bid Capacity (MW)': 100, 'Bid Price (€/MWh)': 200}, # Bid for your oil power plant
    {'Bid Capacity (MW)': 900, 'Bid Price (€/MWh)': 50}, # Bid for your coal power plant
    {'Bid Capacity (MW)': 300, 'Bid Price (€/MWh)': 70}, # Bid for your gas (CCGT) power plant
    {'Bid Capacity (MW)': 400, 'Bid Price (€/MWh)': 100}, # Bid for your gas (OCGT) power plant
    {'Bid Capacity (MW)': 200, 'Bid Price (€/MWh)': 0}, # Bid for your wind power plant
    {'Bid Capacity (MW)': 200, 'Bid Price (€/MWh)': 0} # Bid for your solar power plant
    ]

simulation_company_4.set_model_param('Company4', 'bids_manual', your_bids)
simulation_company_4.set_model_state('Operator1', 'demand', demand)

simulation_company_4.run()
# Out:
# 2026-02-20 11:56:26.846 | INFO     | mosaik.async_scenario:start:508 - Starting 'Collector-0' (based on starter 'Collector')
# 2026-02-20 11:56:28.871 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company1-0' (based on starter 'Company1')
# 2026-02-20 11:56:28.877 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:28.877 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company2-0' (based on starter 'Company2')
# 2026-02-20 11:56:28.882 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company2-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:28.882 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company3-0' (based on starter 'Company3')
# 2026-02-20 11:56:28.885 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company3-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:28.887 | INFO     | mosaik.async_scenario:start:508 - Starting 'Company4-0' (based on starter 'Company4')
# 2026-02-20 11:56:28.892 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Company4-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:28.895 | INFO     | mosaik.async_scenario:start:508 - Starting 'Operator1-0' (based on starter 'Operator1')
# 2026-02-20 11:56:28.897 | WARNING  | mosaik.async_scenario:user_warning:360 - d:\Tesi_TU_Delft\educational_material\.tutorial2venv\lib\site-packages\mosaik\adapters.py:120: UserWarning: Simulator Operator1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2026-02-20 11:56:28.897 | INFO     | mosaik.async_scenario:run:1008 - Starting simulation.
# 2026-02-20 11:56:29.040 | INFO     | mosaik.async_scenario:run:1045 - Simulation finished successfully.

# %%
functions_T2.create_merit_order_curve( all_bids_sorted_csv = r'./results_operator/all_bids_sorted_0.csv', demand = demand, market_result_csv= r'./out_Tutorial2_company4.csv', date = '2024-01-01')
