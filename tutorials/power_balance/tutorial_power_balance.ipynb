# %% [markdown]
# # Practical Power Balancing for a Local Community

# %% [markdown]
# #### Importing the needed packages
# The first step in every python notebook is to install the needed packages (e.g. [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) for data management) as well as functions and classes from external scripts.

# %%
# If running notebook within Google colab, install illuminator and clone educational_material repo to access notebook supporting data
if "google.colab" in str(get_ipython()):
  # !pip install Illuminator
  # !git clone https://github.com/Illuminator-team/educational_material.git

# %%
# If running notebook within Google colab, access the right path of the educational material repo
if "google.colab" in str(get_ipython()):
  import sys
  sys.path.append('/content/educational_material/tutorials/power_balance/')
  # %cd /content/educational_material/tutorials/power_balance/
# Out:
# /content/educational_material/tutorials/power_balance

# %%
from illuminator.engine import Simulation
import functions_T1
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# In this tutorial a neighbourhood is connected to the grid as sketched below. For a typical day in the year the neighbourhood has a given demand profile (load_data.txt file). The given load data is for a year and is given in 15 minute intervals. This electricity demand must be fulfilled.

# %% [markdown]
# #### Task 1: Load Profile for a Neighbourhood
#
# In the first task entails the neighbourhood takes all electricity from the grid. The demand of the neighbourhood can be visualized in a load profile for a day of choice. The following python code plots a specified day based on the given load data and the specified number of houses in the neighbourhood. Electricity from the grid comes from various sources. The energy mix of the Netherlands can be found under https://www.iea.org/countries/the-netherlands/energy-mix. In the code the load data is first saved in a pandas dataframe and it is ensured that the index is the time. Then the day is chosen and a function is called to plot the load data on this day.
# <br> <br> Run the code and describe what you can see in the plot (certain regular peaks, irregularities, etc.). You can vary the day for which you want to plot the load with the day_of_year parameter. Here, you can also compare the load on different days.

# %% [markdown]
# ![T1_basecase](https://github.com/Illuminator-team/educational_material/blob/main/tutorials/power_balance/images/neighbourhood_base_case_T1.png?raw=1)

# %%
load_df = pd.read_csv('data/load_data.txt', delimiter=',', skiprows=1)
load_df['time'] = pd.to_datetime(load_df['time'])
load_df.set_index('time', inplace=True)
#choose which day of the year to plot
day_of_year = "2012-06-01"
number_houses = 5
plot_load_base_case = functions_T1.plot_load_profile(load_df, day_of_year, number_houses)

# %% [markdown]
# The community implements small scale PV and wind power plants to become more autonomous. Now first the supply from the local renewable energy sources is used to cover the demand in the community. The residual load is then supplied by the grid. In case of excess renewable generation the generated electricity is fed into the grid.

# %% [markdown]
# ![T1_RES_case](https://github.com/Illuminator-team/educational_material/blob/main/tutorials/power_balance/images/neighbourhood_RES_case_T1.png?raw=1)

# %% [markdown]
# #### Task 2: Neighbourhood with local RES
#
# In the below presented code the simulation of the neighbourhood's system is set up. The configuration of the system with a Wind, PV and Load model is specified in the yaml file 'Tutorial_Power_Balance_a.yaml'. Next the input data for the three different models is loaded. Then, the parameters 'p_rated' of the Wind model, 'houses' of the load model and 'cap' of the PV model are updated in the simulation with the edit_models() function. Afterwards, the simulation start and end time is set with the set_scenario_param() function. With the run() function the simulation is executed and the results are saved in an ouput file './out_Tutorial_Power_Balance_a.csv'. Finally, the summarise_results function creates a plot and an hourly table with the key results.
#
# a) Run the following python code and look at the resulting residual load plot. Describe the plot and compare it to the results from task 1. How did the load change for the different days you tested in task 1?
#
# b) Vary the installed PV and Wind power as well as the number of houses in the neighbourhood and describe your findings. Here are a few suggested changes for the parameter values to get you started:
#
#         - No wind turbines: 'Wind1': {'p_rated': 0}
#
#         - No PV: 'PV1':{'cap': 0}
#
#         - Increased Load: 'Load1': {'houses': 10}
#
#         - More installed capacity wind turbines: 'Wind1': {'p_rated': 3}
#
#         - More installed capacity PV:   'PV1':{'cap': 5000}
#
# Tip: Try every parameter change on its own first. Then combine changes such as no wind turbines and more installed PV capacity. Also try your own parameter changes and observe the effect.

# %%
# %%capture
CONFIG_FILE = 'data/Tutorial_Power_Balance_a.yaml'
simulation_RES = Simulation(CONFIG_FILE)
simulation_RES.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')

new_settings = {'Wind1': {'p_rated': 0.3}, # installed capacity of the Wind turbine (in kW), default = 0.3
                'Load1': {'houses': 5}, # number of houses in the neighbourhood, default = 5
                'PV1':{'cap': 500} # installed capacity of the PV modules in the neighbourhood (in W), default = 500
                }

# Update Model Parameters
simulation_RES.edit_models(new_settings)

# Update simulation start and end
simulation_RES.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES.run()
# Out:
# 2025-12-02 09:32:14.332 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-12-02 09:32:15.031 | INFO     | mosaik.async_scenario:start:420 - Starting "CSVload" as "CSVload-0" ...
# 2025-12-02 09:32:15.822 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator CSVload-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:15.823 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_pv" as "CSV_pv-0" ...
# 2025-12-02 09:32:16.565 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator CSV_pv-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:16.566 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_wind" as "CSV_wind-0" ...
# 2025-12-02 09:32:17.301 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator CSV_wind-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:17.302 | INFO     | mosaik.async_scenario:start:420 - Starting "Load1" as "Load1-0" ...
# 2025-12-02 09:32:17.303 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator Load1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:17.306 | INFO     | mosaik.async_scenario:start:420 - Starting "PV1" as "PV1-0" ...
# 2025-12-02 09:32:17.309 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator PV1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:17.310 | INFO     | mosaik.async_scenario:start:420 - Starting "Wind1" as "Wind1-0" ...
# 2025-12-02 09:32:17.312 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator Wind1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:17.313 | INFO     | mosaik.async_scenario:start:420 - Starting "Controller1" as "Controller1-0" ...
# 2025-12-02 09:32:17.315 | WARNING  | mosaik.async_scenario:user_warning:342 - /usr/local/lib/python3.12/dist-packages/mosaik/adapters.py:98: UserWarning: Simulator Controller1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-12-02 09:32:17.317 | INFO     | mosaik.async_scenario:run:789 - Starting simulation.
# 2025-12-02 09:32:17.953 | INFO     | mosaik.async_scenario:run:845 - Simulation finished successfully.

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_a.csv', battery_active = False)
# Out:
# <style type="text/css">
# #T_e247d_row0_col0, #T_e247d_row0_col1, #T_e247d_row0_col2, #T_e247d_row0_col3, #T_e247d_row0_col4, #T_e247d_row0_col5, #T_e247d_row1_col0, #T_e247d_row1_col1, #T_e247d_row1_col2, #T_e247d_row1_col3, #T_e247d_row1_col4, #T_e247d_row1_col5, #T_e247d_row2_col0, #T_e247d_row2_col1, #T_e247d_row2_col2, #T_e247d_row2_col3, #T_e247d_row2_col4, #T_e247d_row2_col5, #T_e247d_row3_col0, #T_e247d_row3_col1, #T_e247d_row3_col2, #T_e247d_row3_col3, #T_e247d_row3_col4, #T_e247d_row3_col5, #T_e247d_row4_col0, #T_e247d_row4_col1, #T_e247d_row4_col2, #T_e247d_row4_col3, #T_e247d_row4_col4, #T_e247d_row4_col5, #T_e247d_row5_col0, #T_e247d_row5_col1, #T_e247d_row5_col2, #T_e247d_row5_col3, #T_e247d_row5_col4, #T_e247d_row5_col5, #T_e247d_row6_col0, #T_e247d_row6_col1, #T_e247d_row6_col2, #T_e247d_row6_col3, #T_e247d_row6_col4, #T_e247d_row6_col5, #T_e247d_row7_col0, #T_e247d_row7_col1, #T_e247d_row7_col2, #T_e247d_row7_col3, #T_e247d_row7_col4, #T_e247d_row7_col5, #T_e247d_row8_col0, #T_e247d_row8_col1, #T_e247d_row8_col2, #T_e247d_row8_col3, #T_e247d_row8_col4, #T_e247d_row8_col5, #T_e247d_row9_col0, #T_e247d_row9_col1, #T_e247d_row9_col2, #T_e247d_row9_col3, #T_e247d_row9_col4, #T_e247d_row9_col5, #T_e247d_row10_col0, #T_e247d_row10_col1, #T_e247d_row10_col2, #T_e247d_row10_col3, #T_e247d_row10_col4, #T_e247d_row10_col5, #T_e247d_row11_col0, #T_e247d_row11_col1, #T_e247d_row11_col2, #T_e247d_row11_col3, #T_e247d_row11_col4, #T_e247d_row11_col5, #T_e247d_row12_col0, #T_e247d_row12_col1, #T_e247d_row12_col2, #T_e247d_row12_col3, #T_e247d_row12_col4, #T_e247d_row12_col5, #T_e247d_row13_col0, #T_e247d_row13_col1, #T_e247d_row13_col2, #T_e247d_row13_col3, #T_e247d_row13_col4, #T_e247d_row13_col5, #T_e247d_row14_col0, #T_e247d_row14_col1, #T_e247d_row14_col2, #T_e247d_row14_col3, #T_e247d_row14_col4, #T_e247d_row14_col5, #T_e247d_row15_col0, #T_e247d_row15_col1, #T_e247d_row15_col2, #T_e247d_row15_col3, #T_e247d_row15_col4, #T_e247d_row15_col5, #T_e247d_row16_col0, #T_e247d_row16_col1, #T_e247d_row16_col2, #T_e247d_row16_col3, #T_e247d_row16_col4, #T_e247d_row16_col5, #T_e247d_row17_col0, #T_e247d_row17_col1, #T_e247d_row17_col2, #T_e247d_row17_col3, #T_e247d_row17_col4, #T_e247d_row17_col5, #T_e247d_row18_col0, #T_e247d_row18_col1, #T_e247d_row18_col2, #T_e247d_row18_col3, #T_e247d_row18_col4, #T_e247d_row18_col5, #T_e247d_row19_col0, #T_e247d_row19_col1, #T_e247d_row19_col2, #T_e247d_row19_col3, #T_e247d_row19_col4, #T_e247d_row19_col5, #T_e247d_row20_col0, #T_e247d_row20_col1, #T_e247d_row20_col2, #T_e247d_row20_col3, #T_e247d_row20_col4, #T_e247d_row20_col5, #T_e247d_row21_col0, #T_e247d_row21_col1, #T_e247d_row21_col2, #T_e247d_row21_col3, #T_e247d_row21_col4, #T_e247d_row21_col5, #T_e247d_row22_col0, #T_e247d_row22_col1, #T_e247d_row22_col2, #T_e247d_row22_col3, #T_e247d_row22_col4, #T_e247d_row22_col5, #T_e247d_row23_col0, #T_e247d_row23_col1, #T_e247d_row23_col2, #T_e247d_row23_col3, #T_e247d_row23_col4, #T_e247d_row23_col5 {
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_e247d" class="dataframe">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e247d_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_e247d_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_e247d_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_e247d_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_e247d_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_e247d_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e247d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e247d_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_e247d_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_e247d_row0_col2" class="data row0 col2" >7.74</td>
#       <td id="T_e247d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e247d_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_e247d_row0_col5" class="data row0 col5" >6.67</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e247d_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_e247d_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_e247d_row1_col2" class="data row1 col2" >6.72</td>
#       <td id="T_e247d_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_e247d_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_e247d_row1_col5" class="data row1 col5" >5.9</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e247d_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_e247d_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_e247d_row2_col2" class="data row2 col2" >3.46</td>
#       <td id="T_e247d_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e247d_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_e247d_row2_col5" class="data row2 col5" >2.66</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e247d_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_e247d_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_e247d_row3_col2" class="data row3 col2" >1.78</td>
#       <td id="T_e247d_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_e247d_row3_col4" class="data row3 col4" >0.78</td>
#       <td id="T_e247d_row3_col5" class="data row3 col5" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e247d_row4_col0" class="data row4 col0" >2012-06-01</td>
#       <td id="T_e247d_row4_col1" class="data row4 col1" >04:00:00</td>
#       <td id="T_e247d_row4_col2" class="data row4 col2" >1.64</td>
#       <td id="T_e247d_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_e247d_row4_col4" class="data row4 col4" >0.35</td>
#       <td id="T_e247d_row4_col5" class="data row4 col5" >1.29</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e247d_row5_col0" class="data row5 col0" >2012-06-01</td>
#       <td id="T_e247d_row5_col1" class="data row5 col1" >05:00:00</td>
#       <td id="T_e247d_row5_col2" class="data row5 col2" >2.55</td>
#       <td id="T_e247d_row5_col3" class="data row5 col3" >0.22</td>
#       <td id="T_e247d_row5_col4" class="data row5 col4" >0.39</td>
#       <td id="T_e247d_row5_col5" class="data row5 col5" >1.95</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e247d_row6_col0" class="data row6 col0" >2012-06-01</td>
#       <td id="T_e247d_row6_col1" class="data row6 col1" >06:00:00</td>
#       <td id="T_e247d_row6_col2" class="data row6 col2" >3.67</td>
#       <td id="T_e247d_row6_col3" class="data row6 col3" >0.43</td>
#       <td id="T_e247d_row6_col4" class="data row6 col4" >0.59</td>
#       <td id="T_e247d_row6_col5" class="data row6 col5" >2.64</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e247d_row7_col0" class="data row7 col0" >2012-06-01</td>
#       <td id="T_e247d_row7_col1" class="data row7 col1" >07:00:00</td>
#       <td id="T_e247d_row7_col2" class="data row7 col2" >3.85</td>
#       <td id="T_e247d_row7_col3" class="data row7 col3" >0.72</td>
#       <td id="T_e247d_row7_col4" class="data row7 col4" >0.23</td>
#       <td id="T_e247d_row7_col5" class="data row7 col5" >2.9</td>
#     </tr>
#     <tr>
#       <th id="T_e247d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e247d_row

# %% [markdown]
# The residents have decided to implement a community storage, to enhance the utilization of their local generation. The electricity generated from the local renewable energy sources is stored in the battery when generation exceeds the local demand. The stored energy is used when the local generation cannot cover the demand.
#
# Thus, the controller connected to the battery acts in the following way: In case of not enough local generation to cover the demand of the neighbourhood electricity is taken from the battery storage if the battery is sufficiently charged. If the battery charge is not enough, electricity is taken from the grid to meet the demand. The storage level of the battery is given by the SOC (State of Charge). The State of Charge of a battery represents the current charge level relative to its full capacity, typically expressed in percentages.  Thus, SOC=100% means the battery is fully charged and SOC=0% means it is fully discharged. To prevent damage the battery has a minimum and maximum SOC (upper and lower boundary) included in the control logic, that cannot be surpassed.

# %% [markdown]
# ![T1_RES_case_Bat](https://github.com/Illuminator-team/educational_material/blob/main/tutorials/power_balance/images/neighbourhood_RES_Bat_case_T1.png?raw=1)

# %% [markdown]
# ### Task 3 Neighbourhood with local RES and Communal Battery
#
# The code below sets up a simulation similar to Task 2. Now, a Battery model is added to the simulation. The parameters 'max_p': 0.8 and 'min_p': -0.8 describe the installed battery capacity in kW. Next to these parameters the initial State of Charge is set with the set_model_state() function. The result plot that is generated with the summarize_results() function now also includes a Power from Grid plot, which represents the electricity supplied by the grid. Additionally, the plot_soc() function generates a plot of the state of charge of the battery over the timespan of the simulation based on the output csv.
#
# a) Run the following python code that simulates a typical day in the local community with renewable generation and battery storage. For this task the State of charge is 90% in the beginning of the day. How does the residual load curve change compared to task 2 (the utilization of small scale local renewable generation without storage).
#
# b) Change the initial State of charge parameter to 50% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# c) Change the initial State of charge parameter to 10% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# d) Try some parameter combinations from Task 2 that you find interesting with different initial State of Charge. What do you observe?

# %%
# %%capture
CONFIG_FILE = 'data/Tutorial_Power_Balance_b.yaml'
simulation_RES_Bat = Simulation(CONFIG_FILE)
simulation_RES_Bat.set_model_param(model_name='CSVload', parameter='file_path', value='data/load_data.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_pv', parameter='file_path', value='data/pv_data_Rotterdam_NL-15min.txt')
simulation_RES_Bat.set_model_param(model_name='CSV_wind', parameter='file_path', value='data/winddata_NL.txt')

new_settings = {'Wind1': {'p_rated': 0.3}, # power in kW
                'Load1': {'houses': 5}, # number of houses
                'PV1':{'cap': 500}, # installed capacity in W
                'Battery1':{'max_p': 0.8, 'min_p': -0.8,'soc_min': 10, 'soc_max': 90}, #max_p, min_p in kW
                }

# Update Model Parameters
simulation_RES_Bat.edit_models(new_settings)

# with this function you can set an initial state of a model such as the soc of the battery
simulation_RES_Bat.set_model_state(model_name='Battery1', state='soc', value=90)

# Update simulation start and end
simulation_RES_Bat.set_scenario_param('start_time', '2012-06-01 00:00:00')
simulation_RES_Bat.set_scenario_param('end_time', '2012-06-01 23:45:00')

# run the simulation
simulation_RES_Bat.run()
# Out:
# 2025-08-18 08:02:09.084 | INFO     | mosaik.async_scenario:start:420 - Starting "Collector" as "Collector-0" ...
# 2025-08-18 08:02:09.481 | INFO     | mosaik_api_v3:start_simulation_async:424 - Starting Collector ...
# 2025-08-18 08:02:09.483 | INFO     | mosaik.async_scenario:start:420 - Starting "CSVload" as "CSVload-0" ...
# 2025-08-18 08:02:09.706 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator CSVload-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:09.707 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_pv" as "CSV_pv-0" ...
# 2025-08-18 08:02:09.930 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator CSV_pv-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:09.931 | INFO     | mosaik.async_scenario:start:420 - Starting "CSV_wind" as "CSV_wind-0" ...
# 2025-08-18 08:02:10.151 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator CSV_wind-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.152 | INFO     | mosaik.async_scenario:start:420 - Starting "Load1" as "Load1-0" ...
# 2025-08-18 08:02:10.152 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator Load1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.153 | INFO     | mosaik.async_scenario:start:420 - Starting "PV1" as "PV1-0" ...
# 2025-08-18 08:02:10.153 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator PV1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.154 | INFO     | mosaik.async_scenario:start:420 - Starting "Wind1" as "Wind1-0" ...
# 2025-08-18 08:02:10.154 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator Wind1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.155 | INFO     | mosaik.async_scenario:start:420 - Starting "Battery1" as "Battery1-0" ...
# 2025-08-18 08:02:10.155 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator Battery1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.156 | INFO     | mosaik.async_scenario:start:420 - Starting "Controller1" as "Controller1-0" ...
# 2025-08-18 08:02:10.156 | WARNING  | mosaik.async_scenario:user_warning:342 - /opt/miniconda3/envs/illuminator-tutorials/lib/python3.11/site-packages/mosaik/adapters.py:98: UserWarning: Simulator Controller1-0 is using an outdated API version, namely 1. It should still work. You can suppress this warning by adding an explicit API version for this simulator in your SimConfig.
# 2025-08-18 08:02:10.157 | INFO     | mosaik.async_scenario:run:789 - Starting simulation.
# 2025-08-18 08:02:10.338 | INFO     | mosaik.async_scenario:run:845 - Simulation finished successfully.
# Collector create: hi
# Collector create: bye

# %%
functions_T1.summarize_results('./out_Tutorial_Power_Balance_b.csv', battery_active = True)
functions_T1.plot_soc('./out_Tutorial_Power_Balance_b.csv',soc_min= 10, soc_max= 90)
# Out:
# <style type="text/css">
# #T_657ac_row0_col0, #T_657ac_row0_col1, #T_657ac_row0_col2, #T_657ac_row0_col3, #T_657ac_row0_col4, #T_657ac_row0_col5, #T_657ac_row0_col6, #T_657ac_row0_col7, #T_657ac_row0_col8, #T_657ac_row1_col0, #T_657ac_row1_col1, #T_657ac_row1_col2, #T_657ac_row1_col3, #T_657ac_row1_col4, #T_657ac_row1_col5, #T_657ac_row1_col6, #T_657ac_row1_col7, #T_657ac_row1_col8, #T_657ac_row2_col0, #T_657ac_row2_col1, #T_657ac_row2_col2, #T_657ac_row2_col3, #T_657ac_row2_col4, #T_657ac_row2_col5, #T_657ac_row2_col6, #T_657ac_row2_col7, #T_657ac_row2_col8, #T_657ac_row3_col0, #T_657ac_row3_col1, #T_657ac_row3_col2, #T_657ac_row3_col3, #T_657ac_row3_col4, #T_657ac_row3_col5, #T_657ac_row3_col6, #T_657ac_row3_col7, #T_657ac_row3_col8, #T_657ac_row4_col0, #T_657ac_row4_col1, #T_657ac_row4_col2, #T_657ac_row4_col3, #T_657ac_row4_col4, #T_657ac_row4_col5, #T_657ac_row4_col6, #T_657ac_row4_col7, #T_657ac_row4_col8, #T_657ac_row5_col0, #T_657ac_row5_col1, #T_657ac_row5_col2, #T_657ac_row5_col3, #T_657ac_row5_col4, #T_657ac_row5_col5, #T_657ac_row5_col6, #T_657ac_row5_col7, #T_657ac_row5_col8, #T_657ac_row6_col0, #T_657ac_row6_col1, #T_657ac_row6_col2, #T_657ac_row6_col3, #T_657ac_row6_col4, #T_657ac_row6_col5, #T_657ac_row6_col6, #T_657ac_row6_col7, #T_657ac_row6_col8, #T_657ac_row7_col0, #T_657ac_row7_col1, #T_657ac_row7_col2, #T_657ac_row7_col3, #T_657ac_row7_col4, #T_657ac_row7_col5, #T_657ac_row7_col6, #T_657ac_row7_col7, #T_657ac_row7_col8, #T_657ac_row8_col0, #T_657ac_row8_col1, #T_657ac_row8_col2, #T_657ac_row8_col3, #T_657ac_row8_col4, #T_657ac_row8_col5, #T_657ac_row8_col6, #T_657ac_row8_col7, #T_657ac_row8_col8, #T_657ac_row9_col0, #T_657ac_row9_col1, #T_657ac_row9_col2, #T_657ac_row9_col3, #T_657ac_row9_col4, #T_657ac_row9_col5, #T_657ac_row9_col6, #T_657ac_row9_col7, #T_657ac_row9_col8, #T_657ac_row10_col0, #T_657ac_row10_col1, #T_657ac_row10_col2, #T_657ac_row10_col3, #T_657ac_row10_col4, #T_657ac_row10_col5, #T_657ac_row10_col6, #T_657ac_row10_col7, #T_657ac_row10_col8, #T_657ac_row11_col0, #T_657ac_row11_col1, #T_657ac_row11_col2, #T_657ac_row11_col3, #T_657ac_row11_col4, #T_657ac_row11_col5, #T_657ac_row11_col6, #T_657ac_row11_col7, #T_657ac_row11_col8, #T_657ac_row12_col0, #T_657ac_row12_col1, #T_657ac_row12_col2, #T_657ac_row12_col3, #T_657ac_row12_col4, #T_657ac_row12_col5, #T_657ac_row12_col6, #T_657ac_row12_col7, #T_657ac_row12_col8, #T_657ac_row13_col0, #T_657ac_row13_col1, #T_657ac_row13_col2, #T_657ac_row13_col3, #T_657ac_row13_col4, #T_657ac_row13_col5, #T_657ac_row13_col6, #T_657ac_row13_col7, #T_657ac_row13_col8, #T_657ac_row14_col0, #T_657ac_row14_col1, #T_657ac_row14_col2, #T_657ac_row14_col3, #T_657ac_row14_col4, #T_657ac_row14_col5, #T_657ac_row14_col6, #T_657ac_row14_col7, #T_657ac_row14_col8, #T_657ac_row15_col0, #T_657ac_row15_col1, #T_657ac_row15_col2, #T_657ac_row15_col3, #T_657ac_row15_col4, #T_657ac_row15_col5, #T_657ac_row15_col6, #T_657ac_row15_col7, #T_657ac_row15_col8, #T_657ac_row16_col0, #T_657ac_row16_col1, #T_657ac_row16_col2, #T_657ac_row16_col3, #T_657ac_row16_col4, #T_657ac_row16_col5, #T_657ac_row16_col6, #T_657ac_row16_col7, #T_657ac_row16_col8, #T_657ac_row17_col0, #T_657ac_row17_col1, #T_657ac_row17_col2, #T_657ac_row17_col3, #T_657ac_row17_col4, #T_657ac_row17_col5, #T_657ac_row17_col6, #T_657ac_row17_col7, #T_657ac_row17_col8, #T_657ac_row18_col0, #T_657ac_row18_col1, #T_657ac_row18_col2, #T_657ac_row18_col3, #T_657ac_row18_col4, #T_657ac_row18_col5, #T_657ac_row18_col6, #T_657ac_row18_col7, #T_657ac_row18_col8, #T_657ac_row19_col0, #T_657ac_row19_col1, #T_657ac_row19_col2, #T_657ac_row19_col3, #T_657ac_row19_col4, #T_657ac_row19_col5, #T_657ac_row19_col6, #T_657ac_row19_col7, #T_657ac_row19_col8, #T_657ac_row20_col0, #T_657ac_row20_col1, #T_657ac_row20_col2, #T_657ac_row20_col3, #T_657ac_row20_col4, #T_657ac_row20_col5, #T_657ac_row20_col6, #T_657ac_row20_col7, #T_657ac_row20_col8, #T_657ac_row21_col0, #T_657ac_row21_col1, #T_657ac_row21_col2, #T_657ac_row21_col3, #T_657ac_row21_col4, #T_657ac_row21_c ...
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_657ac">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_657ac_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_657ac_level0_col1" class="col_heading level0 col1" >Time</th>
#       <th id="T_657ac_level0_col2" class="col_heading level0 col2" >Load Demand (kW)</th>
#       <th id="T_657ac_level0_col3" class="col_heading level0 col3" >PV Generation (kW)</th>
#       <th id="T_657ac_level0_col4" class="col_heading level0 col4" >Wind Generation (kW)</th>
#       <th id="T_657ac_level0_col5" class="col_heading level0 col5" >Residual Load (kW)</th>
#       <th id="T_657ac_level0_col6" class="col_heading level0 col6" >Battery SOC (%)</th>
#       <th id="T_657ac_level0_col7" class="col_heading level0 col7" >Power to Battery (kW)</th>
#       <th id="T_657ac_level0_col8" class="col_heading level0 col8" >Power to Grid (kW)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_657ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_657ac_row0_col0" class="data row0 col0" >2012-06-01</td>
#       <td id="T_657ac_row0_col1" class="data row0 col1" >00:00:00</td>
#       <td id="T_657ac_row0_col2" class="data row0 col2" >30.97</td>
#       <td id="T_657ac_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_657ac_row0_col4" class="data row0 col4" >1.08</td>
#       <td id="T_657ac_row0_col5" class="data row0 col5" >29.9</td>
#       <td id="T_657ac_row0_col6" class="data row0 col6" >90</td>
#       <td id="T_657ac_row0_col7" class="data row0 col7" >-1.68</td>
#       <td id="T_657ac_row0_col8" class="data row0 col8" >-28.22</td>
#     </tr>
#     <tr>
#       <th id="T_657ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_657ac_row1_col0" class="data row1 col0" >2012-06-01</td>
#       <td id="T_657ac_row1_col1" class="data row1 col1" >01:00:00</td>
#       <td id="T_657ac_row1_col2" class="data row1 col2" >26.86</td>
#       <td id="T_657ac_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_657ac_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_657ac_row1_col5" class="data row1 col5" >26.04</td>
#       <td id="T_657ac_row1_col6" class="data row1 col6" >31.77</td>
#       <td id="T_657ac_row1_col7" class="data row1 col7" >-0.46</td>
#       <td id="T_657ac_row1_col8" class="data row1 col8" >-25.59</td>
#     </tr>
#     <tr>
#       <th id="T_657ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_657ac_row2_col0" class="data row2 col0" >2012-06-01</td>
#       <td id="T_657ac_row2_col1" class="data row2 col1" >02:00:00</td>
#       <td id="T_657ac_row2_col2" class="data row2 col2" >13.82</td>
#       <td id="T_657ac_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_657ac_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_657ac_row2_col5" class="data row2 col5" >13.03</td>
#       <td id="T_657ac_row2_col6" class="data row2 col6" >15.92</td>
#       <td id="T_657ac_row2_col7" class="data row2 col7" >-0.12</td>
#       <td id="T_657ac_row2_col8" class="data row2 col8" >-12.91</td>
#     </tr>
#     <tr>
#       <th id="T_657ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_657ac_row3_col0" class="data row3 col0" >2012-06-01</td>
#       <td id="T_657ac_row3_col1" class="data row3 col1" >03:00:00</td>
#       <td id="T_657ac_row3_col2" class="data r
